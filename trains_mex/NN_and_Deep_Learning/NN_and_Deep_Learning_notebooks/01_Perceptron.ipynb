# %% [markdown]
# # 01 Perceptron
#
# **Adapted from Adrin Jalali's talk**
#
# https://github.com/adrinjalali/2017-05-talk-dl

# %% [markdown]
# # Review Comments: none

# %% [markdown]
# ## Perceptron
# * linear binary classifier
# * simplest neural network with a single neuron (by [Rosenblatt, 1957](https://blogs.umass.edu/brain-wars/files/2016/03/rosenblatt-1957.pdf))
#     * one or more inputs with weights
#     * processor with **activation function**
#     * single output
# * feed forward model: from left to right (non-cyclical)

# %% [markdown]
# ### Artificial Neuron (Perceptron - 1957)
# [Source](http://natureofcode.com/book/chapter-10-neural-networks/)
#
# ![](http://natureofcode.com/book/imgs/chapter10/ch10_05.png)
#
# $$output = f(x \times w_x + y \times w_y)$$
# $$f(x) = sign(x)$$
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Signum_function.svg/200px-Signum_function.svg.png)

# %% [markdown]
# ### Classification
#
# ![](http://natureofcode.com/book/imgs/chapter10/ch10_04.png)

# %% [markdown]
# #### Add bias
# ![](http://natureofcode.com/book/imgs/chapter10/ch10_06.png)
#
# $$output = f(x \times w_x + y \times w_y + bias \times w_{bias})$$
# $$f(x) = sign(x)$$

# %% [markdown]
# #### Feed the data
# ![](http://natureofcode.com/book/imgs/chapter10/ch10_07.png)

# %% [markdown]
# ### Derive the weight update formula
#
# $$output = sign(x \times w_x + y \times w_y + b \times w_b)$$
#
# $$error = desired - output$$
#
# $$w_{new} = w + \Delta w$$
#
# $$\Delta w = error \times input$$
#
# $$\Delta w =  error \times input \times \text{learning rate}$$

# %% [markdown]
# ### Linear Separability
#
# ![](http://natureofcode.com/book/imgs/chapter10/ch10_12.png)
# ![](http://natureofcode.com/book/imgs/chapter10/ch10_13.png)

# %% [markdown]
# ## Classification
#
# ### Logical OR
#
# #### Initialize variables

# %%
import numpy as np
import math

sign = lambda x: math.copysign(1, x)

def f(X, W):
    return sign(sum([x * w for x, w in zip(X, W)]))

data = np.array([[0, 0, 1],
                 [1, 0, 1],
                 [0, 1, 1],
                 [1, 1, 1]])
output = np.array([-1, 1, 1, 1])

W = np.random.normal(0, size=3)

# %% [markdown]
# #### Error

# %%
for i in range(len(data)):
    print('desired: %2d, expected: %2d, error: %2d' % 
          (f(data[i], W), 
           output[i],
           output[i] - f(data[i], W)))
# Out:
# desired:  1, expected: -1, error: -2
# desired:  1, expected:  1, error:  0
# desired:  1, expected:  1, error:  0
# desired:  1, expected:  1, error:  0

# %%
def total_error(X, W, y):
    return sum([abs(y[i] - f(X[i,], W)) for i in range(len(X))])

# %% [markdown]
# #### Update Weights

# %%
def new_w(X, W, y, learning_rate):
    output = f(X, W)
    error = y - output
    delta_w = np.array([error * x * learning_rate for x in X])
    return W + delta_w

# %% [markdown]
# #### Train

# %%
learning_rate = 0.5
print('starting error: %2g' % total_error(data, W, output))

for epoch in range(100):
    for i in range(len(data)):
        W = new_w(data[i,:], W, output[i], learning_rate)
        
    print('error: %2g, W: %s' % (total_error(data, W, output), str(W)))
    if total_error(data, W, output) == 0:
        break
# Out:
# starting error:  2
# error:  2, W: [0.99394049 0.59766012 1.38865751]
# error:  2, W: [0.99394049 0.59766012 0.38865751]
# error:  2, W: [0.99394049 1.59766012 0.38865751]
# error:  0, W: [ 0.99394049  1.59766012 -0.61134249]

# %% [markdown]
# ### Logical AND
#
# #### Initialize variables

# %%
data = np.array([[0, 0, 1],
                 [1, 0, 1],
                 [0, 1, 1],
                 [1, 1, 1]])
output = np.array([-1, -1, -1, 1])

W = np.random.normal(0, size=3)

# %% [markdown]
# #### Train

# %%
learning_rate = 0.5
print('starting error: %2g' % total_error(data, W, output))

for epoch in range(100):
    for i in range(len(data)):
        W = new_w(data[i,:], W, output[i], learning_rate)
        
    print('error: %2g, W: %s' % (total_error(data, W, output), str(W)))
    if total_error(data, W, output) == 0:
        break
# Out:
# starting error:  6
# error:  4, W: [-1.11307991  1.06803715 -0.37691633]
# error:  2, W: [-0.11307991  1.06803715 -0.37691633]
# error:  4, W: [ 0.88692009  1.06803715 -0.37691633]
# error:  4, W: [ 0.88692009  2.06803715 -0.37691633]
# error:  2, W: [ 0.88692009  2.06803715 -1.37691633]
# error:  4, W: [ 1.88692009  2.06803715 -1.37691633]
# error:  0, W: [ 0.88692009  2.06803715 -2.37691633]

# %% [markdown]
# ### Logical XOR
#
# #### Initialize variables

# %%
data = np.array([[0, 0, 1],
                 [1, 0, 1],
                 [0, 1, 1],
                 [1, 1, 1]])
output = np.array([-1, 1, 1, -1])

W = np.random.normal(0, size=3)

# %% [markdown]
# #### Train

# %%
learning_rate = 0.1
print('starting error: %2g' % total_error(data, W, output))

for epoch in range(100):
    for i in range(len(data)):
        W = new_w(data[i,:], W, output[i], learning_rate)
        
    print('error: %2g, W: %s' % (total_error(data, W, output), str(W)))
    if total_error(data, W, output) == 0:
        break
# Out:
# starting error:  4
# error:  6, W: [ 1.26293523 -1.14089032  1.08778587]
# error:  6, W: [ 1.06293523 -1.14089032  0.88778587]
# error:  6, W: [ 0.86293523 -1.14089032  0.68778587]
# error:  6, W: [ 0.66293523 -1.14089032  0.48778587]
# error:  4, W: [ 0.46293523 -1.14089032  0.28778587]
# error:  4, W: [ 0.46293523 -0.94089032  0.28778587]
# error:  4, W: [ 0.26293523 -0.94089032  0.08778587]
# error:  4, W: [ 0.26293523 -0.74089032  0.08778587]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]

# %% [markdown]
# #### Train (observe more closely)

# %%
learning_rate = 0.1
print('starting error: %2g' % total_error(data, W, output))

for epoch in range(100):
    for i in range(len(data)):
        W = new_w(data[i,:], W, output[i], learning_rate)
        
        print('error: %2g, W: %s' % (total_error(data, W, output), str(W)))
    if total_error(data, W, output) == 0:
        break
# Out:
# starting error:  4
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]
# error:  4, W: [ 0.06293523 -0.54089032 -0.11221413]
# error:  4, W: [ 0.26293523 -0.54089032  0.08778587]
# error:  6, W: [ 0.26293523 -0.34089032  0.28778587]
# error:  4, W: [ 0.06293523 -0.54089032  0.08778587]

# %% [markdown]
# #### Multilayer perceptron
# ![](http://natureofcode.com/book/imgs/chapter10/ch10_14.png)
