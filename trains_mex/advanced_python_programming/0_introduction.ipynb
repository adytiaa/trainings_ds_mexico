# %% [markdown]
# # Python Basics
#
# ## Resources
# https://docs.python.org/3/tutorial/index.html
# https://developers.google.com/edu/python/
# https://wiki.python.org/moin/BeginnersGuide/Programmers
#
#
# ## General Facts
# * What is a programming language?
# * Differences in programming languages
# * Founded/Developt
# * different versions / ongoing development
# * What is special about Python? / Why is Python so popular?
# * Packages
# * Pros (easy) and cons (speed) and workarounds (c packages)
# * pep8
# *
#
# ## Setup
# * Installing Python: Linux, Mac, Windows
# * my first python program (py file, run over terminal)
# * Python shell in the terminal
# * pip/conda
# * ipython and jupyter
# * notebooks and what is amazing about them
# * jupyter extensions
# * ...
#
# ## Package Managers
# * conda
# * pip
#
#
# ## Variables in Python
#
# ## Data Types
# string, int, float, ...
#
# ### Strings
# #### String Methods
# contains, len? lower, upper, strip, startswith, endswith, find, replace, split, join
# #### String Slices
#
# ### Numbers
# #### Methods?
#
# ### Boolean
#
#
# ## Data Structures
# https://docs.python.org/3/tutorial/datastructures.html
# lists, dictionaries, sets, tuples
#
# ### Lists
# #### List Methods
# append, insert, extend, index, remove, sort, reverse, pop
#
# ### Tuples and Sequences
#
# ### Sets
#
# #### Set Methods
#
# #### Set Operations
# &, |, ^ ...
#
# ### Dictionaries
# #### Dictionary Methods
# keys(), values(), items(), ...
#
#
#
#
# ## Conditions and Control Flow / Logical Expressions
# if
# and/or
#
# ## Loops
# for
# while
#
# break, continue statements
#
# iterators
#
# ## Functions
# * build in functions: len(), range(), print() ...
# * printing (with variables)
# * writing your own functions: and pass statements
#   * default argument values
#   * keyword arguments
#
#
#
# ## Classes
# https://docs.python.org/3/tutorial/classes.html
# ### Names and Objects
# ### Python Scopes and Namespaces
# ### Python Classes
# ### Inheritance
# ### Private Variables
# ### Odds and Ends
# ### Iterators
# ### Generators
#
# ## Advanced
# iterators, keys() and values(), in,
# list comprehensions, list slicing, lambda
# sorting
# input and output
# regular expressions
#
# ## Modules and Packages
# https://docs.python.org/3/tutorial/modules.html
# * what is a module?
# * how to import a module?
# * what is a package?
# "collection of modules"
# * important modules/packages
#   * build-in: sys, os, os.path?, operator?
#   * external: numpy, pandas, sckit-learn, matplotlib,...
#
#
# ## Input and Output
# string formatting
# reading and writing files
#
# ## Logging
# the logging library
#
# ## Error Handling and Exceptions
# ### Syntax Errors
# ### Exceptions
# ### Handling Exceptions
# ### Raising Exceptions
# ### User-defined Exceptions
# ### finally clause
# defining clean-up actions
# ### with statement
# predefined clean-up actions
#
#
# ## Coding Guidelines: PEP8
# * Why? (maintainability!)
# * Documentation
# * 4 space indentation, no tabs
# * line length: do not exceed 79 characters
# * blank lines
# * comments in separate line
# * docstrings
# * use of spaces (around operators and after commas)
# * naming convensions
# * no fancy encodings
# * discussion
# *
#
# ## Testing
#
# https://en.wikipedia.org/wiki/Regression_testing
#
# https://github.com/amueller/COMS4995-s19/blob/master/slides/aml-02-python-git-testing/index.html
#
# ### What is Testing?
#
# ### Type of Tests
# * **Unit tests:** function does the right thing
# * **Integration tests:** system/process does the right thing
# * **Non-regression tests:** bug got removed and will not be introduced
#
# ### What can you Test?
#
# in your future job: test always everything
#
# ### Why Testing?
# you can assume that software without tests is broken.
# * ensure that code works correctly
# * ensure that changes do not break anything
# * ensure that bugs are not reintroduced
# * ensure robustness to user errors
# * ensure code is reachable
# * costs of software bugs!
#
#
#
# ### how to write code that can be tested?
#
# * py.test: https://docs.pytest.org/en/latest/
#   * executes all test*.py files
#   * runs all test* methods
#
# #### Pytest Example
# ...
#
#
#
# ### Test-driven Development
# development approach/philosophy
#
# *you write the tests before the code
#
# ### What makes testing difficult?
# * edge cases
# * time consuming
# * ML / Data Science problems: how to test them?
#
# ### Continuous Integration
# * run tests automatically
# * clear declaration of dependencies
#
# ## Python Community
# ### Organizations
# ### Conferences
# ### Meetups and Events
#
# ## Contribution
#
# ## Further Related Topics
# * git

# %% [markdown]
# check python cookbook for advanced methods
